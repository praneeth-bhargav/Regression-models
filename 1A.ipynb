# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import beta

# %%
a,b =2,2
x = np.linspace(0,1,100)
y = beta.pdf(x,a,b)
plt.figure(figsize=(4,4))
plt.plot(x, beta.pdf(x, a, b), 'g')
plt.title('Beta Distribution', fontsize='12')
plt.xlabel('X', fontsize='12')
plt.ylabel('Probability density (PDF)', fontsize='12')
plt.show()

# %%
# after the first data, 40 out of 50 liked the update
a,b =42,12
x = np.linspace(0,1,100)
y = beta.pdf(x,a,b)
plt.figure(figsize=(4,4))
plt.plot(x, beta.pdf(x, a, b), 'g')
plt.title('Beta Distribution', fontsize='12')
plt.xlabel('X', fontsize='12')
plt.ylabel('Probability density (PDF)', fontsize='12')
plt.show()

# %%
a,b =55,29
x = np.linspace(0,1,100)
y = beta.pdf(x,a,b)
plt.figure(figsize=(4,4))
plt.plot(x, beta.pdf(x, a, b), 'g')
plt.title('Beta Distribution', fontsize='12')
plt.xlabel('X', fontsize='12')
plt.ylabel('Probability density (PDF)', fontsize='12')
plt.show()

# %%
a,b =125,59
x = np.linspace(0,1,100)
y = beta.pdf(x,a,b)
plt.figure(figsize=(4,4))
plt.plot(x, beta.pdf(x, a, b), 'g')
plt.title('Beta Distribution', fontsize='10')
plt.xlabel('X', fontsize='10')
plt.ylabel('Probability density (PDF)', fontsize='10')
plt.show()
